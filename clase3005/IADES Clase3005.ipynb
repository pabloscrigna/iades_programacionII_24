# %% [markdown]
# <font size="6" color="rgb(128, 128, 0)">Funciones II</font>

# %% [markdown]
# * Argumentos y paŕametros
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Objetivos

# %% [markdown]
# * __Reconocer__ los tipos de argumentos y párametros.
#
# * __Aplicar__ funciones recursivas e integradas.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Argumentos y Parámetros

# %% [markdown]
# #### Definicion

# %% [markdown]
# En la definición de la función, las variables o valores se denominan parámetros:

# %%
# definicion
# numero1 y numero2 son los parametros de la función suma

def suma(numero1, numero2):
  return numero1 + numero2

# %% [markdown]
# En la llamada se los denomina argumentos.

# %%
# llamada a la función
# nro1 y nro2 son los argumentos de la funcion suma

nro1 = 23
nro2 = 8
suma(nro1, nro2)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# #### Pasando valores -- Argumentos por posición

# %% [markdown]
# Cuando se envían argumentos a una función, se reciben por orden en los parámetros definidos:

# %%
def suma(a, b):
  return a +b

# %%
suma(7,8)
# Out:
# 15

# %%
nro1 = 5
nro2 = 10

suma(nro1, nro2)
# Out:
# 15

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# #### Argumentos por nombre

# %%
CONST = 5

lista = [0, 56]


suma(lista[0], lista[1])
# Out:
# 39

# %%
suma(b=12, a=3)
# Out:
# 15

# %%
suma(a=nro2, b=nro1)
# Out:
# 15

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# #### Llamada sin argumentos

# %%
def saludar(nombre="Anonimo"):
  print(f"Hola {nombre}")
  return

# %%
saludar()
# Out:
# Hola Anonimo

# %%
saludar("Juan")
# Out:
# Hola Juan

# %%
saludar(nombre="Juan")
# Out:
# Hola Juan

# %%
def calc(numero1, numero2, operacion="+"):
  if operacion == "+":
    return numero1 + numero2

  if operacion == "-":
    return numero1 - numero2

# %%
numero1 = int(input("ingrese un numero: "))
numero2 = int(input("ingrese un numero: "))


resultado = calc(numero1, numero2)
resultado
# Out:
# ingrese un numero: 6
# ingrese un numero: 8
# 14

# %%
resultado = calc(5,6)

# %%
resultado
# Out:
# 14

# %%
numero1
# Out:
# 6

# %%
numero2
# Out:
# 8

# %%
calc(numero1=numero1, numero2=numero2, operacion="+")
# Out:
# 14

# %%
calc(numero1=numero1, numero2=numero2, operacion="-")
# Out:
# -2

# %% [markdown]
# __Preguntas??__

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# #### Argumentos por Valor y Referencia

# %% [markdown]
# Si hablamos de argumentos tenemos que tener algo en cuenta:
# Cuando **enviamos información a una función** generalmente estos datos se envían por **valor**.
# Eso significa que **se crea una copia dentro de la función de los valores que enviamos en sus propias variables**.

# %%
def incrementador(numero_parametro):
  numero_parametro += 1
  print(f"numero en la funcion: {numero_parametro}")
  return

numero = 10
print(f"numero antes de la funcion: {numero}")
incrementador(numero)
print(f"numero despues de la funcion: {numero}")
# Out:
# numero antes de la funcion: 10
# numero en la funcion: 11
# numero despues de la funcion: 10

# %%
def modificar_lista(lista, objeto):
  lista.append(objeto)
  return

lista = []

print(f"antes: {lista}")
modificar_lista(lista, 4)
print(f"despues: {lista}")
# Out:
# antes: []
# despues: [4]

# %%
def incrementador(numero):
  numero += 1
  print(f"numero en la funcion: {numero}")
  return numero

numero = 10
print(f"numero antes de la funcion: {numero}")
numero = incrementador(numero)
print(f"numero despues de la funcion: {numero}")
# Out:
# numero antes de la funcion: 10
# numero en la funcion: 11
# numero despues de la funcion: 11

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista1 = [0,1]
print(id(lista1))
lista2 = lista1.copy()
print(id(lista2))
# Out:
# 134226651000064
# 134226652524928

# %%
lista1
# Out:
# [0, 1]

# %%
lista2
# Out:
# [0, 1]

# %%
def modificar_lista(lista, objeto):
  lista_interna = lista.copy()
  lista_interna.append(objeto)
  print(f"lista interna: {lista_interna}")
  return

lista = []

print(f"antes: {lista}")
modificar_lista(lista, 4)
print(f"despues: {lista}")
# Out:
# antes: []
# lista interna: [4]
# despues: []

# %% [markdown]
#  **Pero**, hay casos excepcionales, las colecciones, **listas, diccionarios, conjuntos**. Estos datos se envían por **referencia**.

# %%
user = {
    "id": 34,
    "nombre": "pepe",
    "rol" : "admin"
}


def alta_user(user):
  pass

usuario = user.copy()

print(f"usuario: {usuario}")
print(f"user: {user}")

usuario["nombre"] = "juan"
usuario["id"] = 45
rol = "user"
del usuario["rol"]

print(usuario)

alta_user(user)

usuario["nombre"] = "pablo"
usuario["id"] = 78
rol = "user"
del usuario["rol"]
# Out:
# usuario: {'id': 34, 'nombre': 'pepe', 'rol': 'admin'}
# user: {'id': 34, 'nombre': 'pepe', 'rol': 'admin'}
# {'id': 45, 'nombre': 'juan'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-f6f41bffd62f> in <cell line: 28>()
#      26 usuario["id"] = 78
#      27 rol = "user"
# ---> 28 del usuario["rol"]
#      29
#      30
#
# KeyError: 'rol'

# %% [markdown]
# Que significa que se envian por referencia?

# %% [markdown]
# Significa que, en lugar de una copia dentro de la función, **estaremos manejando el dato original**, y si lo modificamos también se verá reflejado en el exterior, es decir, en el conjunto original y no en una copia en la función. Esto debido a que hacen referencia a la variable externa, algo así como un acceso directo.

# %%
# lista

# %%
# Ejemplo con diccionario

# %% [markdown]
# #### Resumen:

# %% [markdown]
# **Paso por valor**: se crea una copia local de la variable dentro de la función.
#
# Los tipos simples **se pasan por valor**: Enteros, flotantes, cadenas, lógicos…

# %% [markdown]
# **Paso por referencia**: Se maneja directamente la variable, los cambios realizados dentro de la función le afectarán también fuera.
#
# Los tipos compuestos **se pasan por referencia**: Listas, diccionarios, tuplas, conjuntos...

# %% [markdown]
# __Entonces__:
#
# ¿Es posible que de alguna forma le digamos a Python cuándo queremos pasar un argumento por referencia o por valor?

# %% [markdown]
# **Respuesta:**

# %%
# Ejemplo : Argumento valor por referencia

# %% [markdown]
# __Preguntas???__

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# #### Argumentos indeterminados

# %% [markdown]
# #### *args

# %% [markdown]
# Permiten definir funciones cuyo número de argumentos es variable. Es decir, podemos definir funciones genéricas que no aceptan un número determinado de parámetros, sino que se “adaptan” al número de argumentos con los que son llamados.

# %%
def suma(*args):
  resultado = 0

  for valor in args:
    print(f"valor: {valor}")
    resultado = resultado + valor
  return resultado

# %%
suma(1,3)
# Out:
# valor: 1
# valor: 3
# 4

# %%
suma(1,2,3,4,5,6,7)
# Out:
# valor: 1
# valor: 2
# valor: 3
# valor: 4
# valor: 5
# valor: 6
# valor: 7
# 28

# %%
suma(2)
# Out:
# valor: 2
# 2

# %% [markdown]
# #### *kwargs

# %% [markdown]
# Los **kwargs nos permiten dar un nombre a cada argumento de entrada, pudiendo acceder a ellos dentro de la función a través de un diccionario.

# %%
def suma_dict(**kwargs):

  resultado = 0

  for clave, valor in kwargs.items():
    print(f"clave: {clave} -- valor: {valor}")
    resultado += valor

  return resultado

# %%
suma_dict(numero1=23, numero2=45, pepe=34, numero3=20)
# Out:
# clave: numero1 -- valor: 23
# clave: numero2 -- valor: 45
# clave: pepe -- valor: 34
# clave: numero3 -- valor: 20
# 122

# %% [markdown]
# __Nota__: args y kwargs se pueden llaman asi por convencion, pero podrian tener otro nombre

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Multiples return

# %%
def dividir(a, b):

  if not b:
    return 0

  return a/b

# %%
dividir(8,4)
# Out:
# 2.0

# %%
3/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-45-f6cc6d14333b> in <cell line: 1>()
# ----> 1 3/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# __Preguntas??__

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Funciones recursivas

# %% [markdown]
# **Recursividad**
#
# Cuando una función se llama a sí misma, tenemos una función recursiva con un comportamiento muy similar al de una sentencia iterativa (if, while, etc.) pero debemos encargarnos de planificar el momento en que dejan de llamarse a sí mismas o tendremos una función recursiva infinita.

# %%
# Funcion recursiva con retorno

# factorial 1 (1!) = 1
# factorial 2 (2!) = 2 * 1
# factorial 3 (3!) = 3 * 2 * 1
# factorial 4 (4!) = 4 * 3 * 2 * 1
# factorial 5 (5!) = 5 * 4 * 3 * 2 * 1

def factorial(numero):

  if numero == 1:
    return numero

  numero = numero * factorial(numero - 1)

  return numero

# %%
print(factorial(4))

# %%
# Funcion recursiva sin retorno

def cuenta_regresiva(numero):
  numero -= 1

  if numero > 0:
    print(numero)
    cuenta_regresiva(numero)

  else:
    print("Booom")

  print(f"Fin de la funcion - numero: {numero}")
  return

# %%
cuenta_regresiva(6)

# %% [markdown]
# __Preguntas???__

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Funciones integradas

# %% [markdown]
# Built-in functions: Son funciones que estan incorporadas en el lenguaje.
#
# Para mas informacion pueden acceder a la [documentación](https://docs.python.org/es/3/library/functions.html)

# %%
# int
int(2.5)

# %%
# str
str(34)

# %%
# round
round(3.45)

# %%
# help
help()

# %%
lista = [0,10,30,40]

for indice, valor in enumerate(lista):
  print(f"indice: {indice} - valor: {valor}")

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Typehints

# %% [markdown]
# * Disponible en python desde la version 3.5
# * No es obligatorio!!!
# * Especificar los tipo de dato de los argumentos de una funcion
# * Especificar el tipo de dato que retorna una funcion
# * Chequeo estatico - no en runtime

# %%
def suma(num1: int, num2: int):

  return num1 + num2

# %%
suma("7","8")
# Out:
# '78'

# %%
def saludar(nombre: str)-> str:
  return f"Hola! {nombre}"

# %%
saludar("Juan")
# Out:
# Hola Juan

# %%
saludar(6)
# Out:
# Hola 6

# %%
nombre : str = "Pepe"
edad : int = 23
edad
# Out:
# 23

# %%
from typing import List

foo = list()

def agregar(lista: List[int], valor: int)-> None:
  lista.append(valor)
  return

# %%
lista = [7,8]

agregar(lista, 7)
lista
# Out:
# [7, 8, 7]

# %%
def saludar_anonimo(nombre=""):
  print(f"Hola, {nombre}")
  return

# %%
saludar_anonimo()
# Out:
# Hola,

# %%
saludar_anonimo("Juan")
# Out:
# Hola, Juan

# %%
from typing import Optional

def saludar_anonimo(nombre: Optional[str] = ""):
  print(f"Hola, {nombre}")
  return

# %%
saludar_anonimo(45)
# Out:
# Hola, 45

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Docstrings

# %% [markdown]
# Documentar funciones

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
def resta(a, b):
  """
  Funcion resta
  Esta funcion resta el param a - pam b
  y retorna el resultado
  """
  return a-b

# %%
help(resta)
# Out:
# Help on function resta in module __main__:
#
# resta(a, b)
#     Funcion resta
#     Esta funcion resta el param a - pam b
#     y retorna el resultado

# %% [markdown]
# __Preguntas??__

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Ejercicios!!!!

# %% [markdown]
# ###![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# Diccionarios
#
# a = { "nombre": "Juan"}
# b = { "edad: 34}

# %%
a = { "nombre": "Juan"}
b = { "edad": 34}

c = {}
print(c)
c = {**c, **b}


c = {**c, **a}

a["nombre"] = "CCCCC"
print(c)
print(a)
# Out:
# {'edad': 34}
# {'nombre': 'CCCCC'}

# %%
frase = "C:/User"
frase = f"{frase}/acceso/"
frase = f"{frase}/roles/usuarios"
frase
# Out:
# 'C:/User/acceso//roles/usuarios'
