# %% [markdown]
# <font size="6" color="rgb(128, 128, 0)"> Listas y Tuplas </font>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### Objetivos de la clase
#
# * __Conocer__ qué es una Lista
# * __Analizar__ similitud y diferencias de listas con string
# * __Comprender__ cómo asignar por slicing
# * __Iniciar__ los primeros pasos con funciones de listas
# * __Definir__ y trabajar con  Tuplas

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ### Listas

# %% [markdown]
# En esta segunda clase vamos a estar hablando de otro tipo de datos, llamado Lista o Array. Python es un lenguaje muy flexible, el cual implementa multitud de tipos distintos por defecto y eso incluye también tipos compuestos de datos, los cuales se utilizan para **agrupar distintos elementos o ítems, por ejemplo variables, o valores, de una forma ordenada, es decir, mantienen el orden en el que se definieron**.

# %%
# Definicion de una lista - los elementos van entre corchetes y separados por coma
# [1,2,3,4,5]

# %%
lista = [1,2,3,4,5]
lista

# %%
# Ejemplo con variables
valor = 45

lista2 = [1,2,3,4,5, valor]
lista2

# %%
# Ver el tipo (type)
type(lista2)

# %%
# Ordenadas
lista1 = ["a", "e", "i"]
lista2 = ["i", "a", "e"]

# lista1 es igual a la lista2 ?
lista1 == lista2

# %%
a = []

# %%
a.append(1)

# %%
a

# %%
a.append(2)
a
b = [2, 1]
a == b

# %% [markdown]
# #### Las listas son heterogeneas
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# Ejemplo1
lista3 = [1, "A", "HOLA", [1,2]]
lista3

# %%
# Ejemplo2 con variables
nombre = "Juan"
edad = 50
altura = 20.5

datos_persona = [nombre, edad, altura]
datos_persona

# %%
type(datos_persona)

# %%
type(datos_persona[0])

# %%
type(datos_persona[1])

# %%
type(datos_persona[2])

# %% [markdown]
# #### Listas y String  -- similitudes
#
# * indice
# * slicing
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
frase = "Hola mundo!"

# %%
frase[0]

# %%
frase[1:4]

# %%
# lista
numeros = [1,2,3,4,5,6]

# %%
# Acceso por indices
numeros[1]

# %%
# Acceso por slicing
numeros[1:5]

# %%
# type lista - type items
lista3 = [0, 1.5, "A", [0,1]]

# %%
type(lista3)

# %%
type(lista3[3])

# %%
lista3[3]

# %% [markdown]
# Cual es la principal diferencia con los strings?
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
frase1 = "Hola"
frase[0] = "1"

# %%
numeros = [0,1,2,3,4,5]
print(numeros)
numeros[0] = 5
print(numeros)

# %%
numeros[0] = "A"
numeros

# %% [markdown]
# Las listas son mutables
#
# Python no exige que sean los mismos valores los que se pueden reasignar.

# %%
#Ejemplo mutabilidad
lista__A = [1,2,3,4,5,6]
lista__B = lista__A

# %%
id(lista__A)

# %%
id(lista__B)

# %%
lista__A[0] = "A"
lista__A

# %%
lista__B

# %%
lista__B[0] = 0
lista__B

# %%
lista__A

# %%
lista__A == lista__B

# %% [markdown]
# Repaso

# %%
lista1 = [0,1]
lista2 = [0,1]

# %%
lista3 = ["a", "e"]
lista4 = lista3

# %%
a = [0, "aer", [1,3,4]]

# %%
a[1]

# %%
a[1][0]

# %%
a[2][0]

# %% [markdown]
# #### Ejemplos
#
# * Borrar valores por slicing
# * Funciones/Metodos de listas
# * append
# * pop
# * count + index
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### Borrar valores por slicing
#
# Otra funcionalidad que podemos utilizar gracias a la mutabilidad de las listas y al slicing es borrar los ítems que queramos de una lista.

# %%
# Borrar valores por slicing
numeros = [1,2,3,4,5]
numeros

# %%
# Borrar todos los valores -- instanciar una lista vacia
numeros[0:3] = ["a", "e"]
numeros

# %% [markdown]
# #### Funciones de lista
#
# En las listas, hay funciones que son muy interesantes e importantes, las funciones integradas. Las listas en Python tienen muchas funciones para utilizar, entre todas ellas vamos a nombrar las más importantes.

# %%
# lista
numeros = [1,2,3,4,5,6,7,8]
numeros

# %%
# append: ingresa un elemento o item al final de la lista
numeros.append(9)
numeros

# %%
# append - operaciones
numeros.append(9*2)
numeros

# %%
numeros

# %%
numeros.append("2")
numeros

# %%
# Recordad definir antes la variable
valores = []

dato = input()
valores.append(dato)
valores

# %%
# pop -- extrae el ultimo elelemnto
numeros.pop()

# %%
numeros

# %%
# Y si quiero sacar de otra posicion?
numeros.pop(0)

# %%
numeros

# %%
# count: cuenta la cantidad de veces que un elemento se repite en la lista
numeros.count("A")

# %%
numeros.count(2)

# %%
# Que pasa si el elemento no esta?
numeros.count("aassddsf")

# %%
# index: busco un item y nos retorna el indice
numeros.index(3)

# %%
# si el item no esta?
numeros.index(10)

# %%
# si hay mas de uno?

# %%
lista1 = [1,2,3, 1]
len(lista1)
lista1

# %%
lista1.count(1)

# %%
lista1.index(1)

# %%
dir(list)

# %% [markdown]
# #### Concatenar
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
lista1 = [1,2,3]
lista2 = ["a", "e", "i"]

lista3 = lista1 + lista2

# %%
lista3

# %%
lista4 = lista2 + lista1
lista4

# %%
codigos = ["verde", "azul"]

"verde" in codigos

# %%
numeros

# %%
1 in numeros

# %%
numeros.index(2)

# %%
a = [1,2,3,5]

"X" in a

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### Tuplas
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# Las tuplas son colecciones de datos **parecidas a las listas**, una de las diferencias es que estas son **inmutables**. Se utilizan para asegurarnos que una colección determinada de datos no se pueda modificar.
# Python utiliza tuplas en algunas funciones para devolver resultados inmutables, por eso, conviene saber identificarlas. A su vez, dependiendo de lo que queramos hacer, **las tuplas pueden ser más rápidas que las listas**.

# %%
# declaracion
(2,4,5,6)

# %%
tupla_1 = (3,4,5,6)

# %%
# type
type(tupla_1)

# %%
# tupla con un elemento
tupla_2 = (45,)
tupla_2

# %%
# Otra forma de definir una tupla
tupla_3 = 2,4,5

# %%
# type
type(tupla_3)

# %%
tupla_3

# %% [markdown]
# #### Heterogeneas
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
tupla_4 = (0, "A", [0,1])
tupla_4

# %% [markdown]
# #### Indice y Slicing
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# tupla
numeros = (1,2,3,4,5,67)

# %%
# lectura -- acceso por indice (index)
numeros[1]

# %%
# lectura -- acceso por slicing
valor = numeros[1:4]
valor

# %% [markdown]
# #### Concatenar
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
tupla_a = (0,1)
tupla_b = (2,3)

tupla_c = tupla_b  + tupla_a
tupla_c

# %% [markdown]
# #### Agregar elementos
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# append
print(tupla_c)
tupla_c = (5,3,0,1)
print(tupla_c)

tupla_c = ()
print(tupla_c)

# %% [markdown]
# #### Mutabilidad
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# Como vimos, hay una diferencia entre listas y tuplas, las listas son mutables (podían reasignar sus ítems), en cambio las tuplas son inmutables, esto significa que no podemos reasignar sus ítems haciendo referencia con el índice.

# %%
# modificacion por indice

# %% [markdown]
# #### Funciones de tuplas
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# longitud de una tupla
numeros = (1,2,3,4,5,6,6,6,6)
len(numeros)

# %%
# count --
numeros.count("6")

# %%
# count -- si el elemento no esta
numeros.count("Z")

# %%
# index

numeros.index(5)

# %%
# si el valor no esta?
numeros.index("2")

# %%
# Anidadas

tuplaA = ("a",2,("A", "B"), [1,2])
tuplaA

# %%
lista1 = [0, (1,2)]

lista1[1]

# %%
lista1[1] = 1

# %%
lista1

# %% [markdown]
# #### Transformacion
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# lista a tupla
lista6 = ["A", 0]
print(lista6)
tupla6 = tuple(lista6)
print(tupla6)
lista6[0] = "B"
print(lista6)
print(tupla6)

# %%
listaA = ["2", "4"]

# %%
tuplaA = tuple(listaA)

# %%
tuplaA

# %%
listaB = list(tuplaA)

# %%
listaB

# %%
tupla = (0,1)
lista = [0,1]

tupla == lista

# %%
# list 2 tuple
lista7 = list(tupla6)
lista7

# %%
tuplax = (0, 1)
tuplay = (2, 4)

tuplax + tuplay

# %% [markdown]
# ## Inmutables
#
# foo = (0, "1234", [0, 1, 2, 3)

# %%
foo = (0, "1234", [1,2,3])

# %%
foo[2].append(7)

# %%
foo

# %%
foo[2] = [1,2,3]

# %%
a = (2,4)
c = (2,4)

# %%
id(a)

# %%
id(c)

# %%
d = c

# %%
id(d)

# %%
id(c)

# %%
lista1  = [1]
lista2 = [1]

# %%
lista1 == lista2

# %%
lista1 is lista2

# %%
lista1 = lista2

# %%
lista1 == lista2

# %%
lista1 is lista2

# %%
# variable en python
# id
# tipo de dato
# valor


a = 5
print(id(a))
print(a)
print(type(a))
